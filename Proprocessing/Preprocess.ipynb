# %% [markdown]
# <h1 style='color:purple' align='center'>Data Science Regression Project: Predicting Home Prices in Banglore</h1>

# %% [markdown]
# Dataset is downloaded from here: https://www.kaggle.com/amitabhajoy/bengaluru-house-price-data

# %% [markdown]
# **Usages for data generations**

# %%
switch_dict = {
    'Agricultural': 1,
    'Commercial': 2,
    'Residential': 3,
    'Other': 4
}

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
matplotlib.rcParams["figure.figsize"] = (20,10)
pd.reset_option('display.float_format')
import xgboost

# %% [markdown]
# <h2 style='color:blue'>Data Load: Load banglore home prices into a dataframe</h2>

# %%
df1 = pd.read_csv("CNF.csv")
df1.head()
# Out:
#    Address_ID        Address  Land_size(Perches)  Price_Scale  \
# 0           6   battaramulla                12.0    per perch
# 1          12         nawala                22.0    per perch
# 2          16  mount lavinia                23.0    per perch
# 3          12         nawala                22.0    per perch
# 4          22      hokandara                11.0  total price
#
#                  Land_type Posted_Date_new  Distance from fort  \
# 0  Commercial, Residential       9/21/2021               11.35
# 1  Commercial, Residential       9/21/2021                9.16
# 2              Residential       9/21/2021               12.89
# 3  Commercial, Residential       9/21/2021                9.16
# 4              Residential       9/21/2021               16.39
#
#    count_govtschools_A  min_dist_govtschools_a  count_govtschools_B  ...  \
# 0                    0                3.099786                    3  ...
# 1                    2                1.530830                   12  ...
# 2                    0                2.727171                    5  ...
# 3                    2                1.530830                   12  ...
# 4                    0                4.673446                    1  ...
#
#    min_dist_nearest_Pvt_Med_center  count_Pvt_Med_Centers  \
# 0                         0.184196                      2
# 1                         2.102498                      0
# 2                         1.188858                      2
# 3                         2.102498                      0
# 4                         4.563302                      0
#
#    min_dist_nearest_Supermarket  count_Supermarkets_within2km  \
# 0                      0.275528                            11
# 1                      0.229320                            17
# 2                      0.113300                            20
# 3                      0.229320                            17
# 4                      1.187704                             5
#
#    min_dist_nearest_Fuel_station  count_Fuel_Stations_within2km  \
# 0                       1.185148                              2
# 1                       1.221396                              4
# 2                       1.052876                              5
# 3                       1.221396                              4
# 4                       0.074059                              1
#
#    Mentioned Price(Rs)  Price per Perch  latitude  longitude
# 0        3,800,000.00     3,800,000.00   6.897929  79.918872
# 1        6,500,000.00     6,500,000.00   6.899527  79.883915
# 2        2,600,000.00     2,600,000.00   6.809737  79.871319
# 3        6,500,000.00     6,500,000.00   6.897027  79.884947
# 4        1,200,000.00       109,090.91   6.884656  79.953253
#
# [5 rows x 37 columns]

# %%
df1.shape
# Out:
# (3125, 37)

# %%
df1.columns
# Out:
# Index(['Address_ID', 'Address', 'Land_size(Perches)', 'Price_Scale',
#        'Land_type', 'Posted_Date_new', 'Distance from fort',
#        'count_govtschools_A', 'min_dist_govtschools_a', 'count_govtschools_B',
#        'min_dist_govtschools_b', 'count_semigovtschools',
#        'min_dist_semigovtschools', 'count_intlschools', 'min_dist_intlschools',
#        'count_uni', 'min_dist_uni', 'min_dist_nearest_express',
#        'min_dist_nearest_railway', 'min_dist_nearest_bank',
#        'count_banks_within_2km', 'min_dist_nearest_FinanceCompany',
#        'count_FinanceCompanies_within_2km', 'min_dist_nearest_Govt_Hospital',
#        'count_Govt_Hospitals', 'min_dist_nearest_Pvt_Hospital',
#        'count_Pvt_Hospital', 'min_dist_nearest_Pvt_Med_center',
#        'count_Pvt_Med_Centers', 'min_dist_nearest_Supermarket',
#        'count_Supermarkets_within2km', 'min_dist_nearest_Fuel_station',
#        'count_Fuel_Stations_within2km', 'Mentioned Price(Rs)',
#        'Price per Perch', 'latitude', 'longitude'],
#       dtype='object')

# %%
df1['Address'].unique()
# Out:
# array(['battaramulla', 'nawala', 'mount lavinia', 'hokandara', 'kaduwela',
#        'thalawathugoda', 'athurugiriya', 'dehiwala', 'piliyandala',
#        'madapatha', 'kesbewa', 'makandana', 'boralesgamuwa', 'kirulapone',
#        'ranala', 'kahathuduwa', 'nugegoda', 'malabe', 'bope', 'pitakotte',
#        'homagama', 'bomiriya', 'diyagama', 'maharagama'], dtype=object)

# %%
df1['Address'].value_counts()
# Out:
# Address
# ranala            350
# makandana         270
# kaduwela          250
# kesbewa           206
# piliyandala       204
# battaramulla      188
# malabe            155
# nugegoda          132
# madapatha         125
# thalawathugoda    122
# bomiriya          121
# nawala            111
# bope              107
# dehiwala          102
# kahathuduwa        91
# homagama           86
# athurugiriya       85
# mount lavinia      79
# boralesgamuwa      59
# pitakotte          58
# maharagama         58
# hokandara          57
# diyagama           56
# kirulapone         53
# Name: count, dtype: int64

# %%
# Assuming df1 is your DataFrame
address_counts = df1['Address'].value_counts()
filtered_addresses = address_counts[address_counts >= 50].index
filtered_df = df1[df1['Address'].isin(filtered_addresses)]
filtered_df['Address'].value_counts()
row_count = filtered_df.shape[0]
print("Number of rows:", row_count)
filtered_df['Address'].value_counts()
# Out:
# Number of rows: 3125
# Address
# ranala            350
# makandana         270
# kaduwela          250
# kesbewa           206
# piliyandala       204
# battaramulla      188
# malabe            155
# nugegoda          132
# madapatha         125
# thalawathugoda    122
# bomiriya          121
# nawala            111
# bope              107
# dehiwala          102
# kahathuduwa        91
# homagama           86
# athurugiriya       85
# mount lavinia      79
# boralesgamuwa      59
# pitakotte          58
# maharagama         58
# hokandara          57
# diyagama           56
# kirulapone         53
# Name: count, dtype: int64

# %% [markdown]
# **Drop features that are not required to build our model**

# %%
df2 = df1.drop(['Land_size(Perches)', 'Price_Scale', 'Distance from fort', 'Mentioned Price(Rs)'], axis='columns')
df2.shape
# Out:
# (3125, 33)

# %% [markdown]
# <h2 style='color:blue'>Data Cleaning</h2>

# %% [markdown]
# **Handle NA values**

# %%
df2.isnull().sum()
# Out:
# Address_ID                           0
# Address                              0
# Land_type                            0
# Posted_Date_new                      0
# count_govtschools_A                  0
# min_dist_govtschools_a               0
# count_govtschools_B                  0
# min_dist_govtschools_b               0
# count_semigovtschools                0
# min_dist_semigovtschools             0
# count_intlschools                    0
# min_dist_intlschools                 0
# count_uni                            0
# min_dist_uni                         0
# min_dist_nearest_express             0
# min_dist_nearest_railway             0
# min_dist_nearest_bank                0
# count_banks_within_2km               0
# min_dist_nearest_FinanceCompany      0
# count_FinanceCompanies_within_2km    0
# min_dist_nearest_Govt_Hospital       0
# count_Govt_Hospitals                 0
# min_dist_nearest_Pvt_Hospital        0
# count_Pvt_Hospital                   0
# min_dist_nearest_Pvt_Med_center      0
# count_Pvt_Med_Centers                0
# min_dist_nearest_Supermarket         0
# count_Supermarkets_within2km         0
# min_dist_nearest_Fuel_station        0
# count_Fuel_Stations_within2km        0
# Price per Perch                      0
# latitude                             0
# longitude                            0
# dtype: int64

# %%
df2.shape
# Out:
# (3125, 33)

# %%
df3 = df2.dropna()
df3.isnull().sum()
# Out:
# Address_ID                           0
# Address                              0
# Land_type                            0
# Posted_Date_new                      0
# count_govtschools_A                  0
# min_dist_govtschools_a               0
# count_govtschools_B                  0
# min_dist_govtschools_b               0
# count_semigovtschools                0
# min_dist_semigovtschools             0
# count_intlschools                    0
# min_dist_intlschools                 0
# count_uni                            0
# min_dist_uni                         0
# min_dist_nearest_express             0
# min_dist_nearest_railway             0
# min_dist_nearest_bank                0
# count_banks_within_2km               0
# min_dist_nearest_FinanceCompany      0
# count_FinanceCompanies_within_2km    0
# min_dist_nearest_Govt_Hospital       0
# count_Govt_Hospitals                 0
# min_dist_nearest_Pvt_Hospital        0
# count_Pvt_Hospital                   0
# min_dist_nearest_Pvt_Med_center      0
# count_Pvt_Med_Centers                0
# min_dist_nearest_Supermarket         0
# count_Supermarkets_within2km         0
# min_dist_nearest_Fuel_station        0
# count_Fuel_Stations_within2km        0
# Price per Perch                      0
# latitude                             0
# longitude                            0
# dtype: int64

# %%
df3.shape
# Out:
# (3125, 33)

# %%
df3.head()
# Out:
#    Address_ID        Address                Land_type Posted_Date_new  \
# 0           6   battaramulla  Commercial, Residential       9/21/2021
# 1          12         nawala  Commercial, Residential       9/21/2021
# 2          16  mount lavinia              Residential       9/21/2021
# 3          12         nawala  Commercial, Residential       9/21/2021
# 4          22      hokandara              Residential       9/21/2021
#
#    count_govtschools_A  min_dist_govtschools_a  count_govtschools_B  \
# 0                    0                3.099786                    3
# 1                    2                1.530830                   12
# 2                    0                2.727171                    5
# 3                    2                1.530830                   12
# 4                    0                4.673446                    1
#
#    min_dist_govtschools_b  count_semigovtschools  min_dist_semigovtschools  \
# 0                0.190254                      0                  3.899165
# 1                0.863357                      1                  0.906167
# 2                0.191582                      2                  0.581298
# 3                0.863357                      1                  0.906167
# 4                0.386004                      0                  4.412525
#
#    ...  count_Pvt_Hospital  min_dist_nearest_Pvt_Med_center  \
# 0  ...                   0                         0.184196
# 1  ...                   5                         2.102498
# 2  ...                   0                         1.188858
# 3  ...                   5                         2.102498
# 4  ...                   0                         4.563302
#
#    count_Pvt_Med_Centers  min_dist_nearest_Supermarket  \
# 0                      2                      0.275528
# 1                      0                      0.229320
# 2                      2                      0.113300
# 3                      0                      0.229320
# 4                      0                      1.187704
#
#    count_Supermarkets_within2km  min_dist_nearest_Fuel_station  \
# 0                            11                       1.185148
# 1                            17                       1.221396
# 2                            20                       1.052876
# 3                            17                       1.221396
# 4                             5                       0.074059
#
#    count_Fuel_Stations_within2km  Price per Perch  latitude  longitude
# 0                              2    3,800,000.00   6.897929  79.918872
# 1                              4    6,500,000.00   6.899527  79.883915
# 2                              5    2,600,000.00   6.809737  79.871319
# 3                              4    6,500,000.00   6.897027  79.884947
# 4                              1      109,090.91   6.884656  79.953253
#
# [5 rows x 33 columns]

# %% [markdown]
# <h2 style='color:blue'>Feature Engineering</h2>

# %% [markdown]
# **Method to check date type is correct**

# %%
def checkTypeDate(df, column_name):
    try:
        # Assuming 'Posted_Date_new' has the format 'mm/dd/yyyy'
        pd.to_datetime(df[column_name], format='%m/%d/%Y', errors='raise')
        
        print(f"Success: {column_name}")
        return True
    except ValueError as ve:
        # Specific handling for the ValueError when conversion fails
        print(f"Error: {column_name}, Error: {ve}")
        return False
    except Exception as e:
        # General handling for other exceptions
        print(f"Error: {column_name}, Unexpected Error: {e}")
        return False

# %%
checkTypeDate(df3, 'Posted_Date_new')
# Out:
# Success: Posted_Date_new
# True

# %% [markdown]
# **Create a current month column**

# %%
def addMonth(value):
    try:
        parts = value.split('/')
        if len(parts) > 1:
            month = float(parts[0])
            if 0 < month < 13:
                return month
        return 7
    except:
        return 7

# %%
df3['current_month'] = df3['Posted_Date_new'].apply(addMonth)
df3.head()
# Out:
#    Address_ID        Address                Land_type Posted_Date_new  \
# 0           6   battaramulla  Commercial, Residential       9/21/2021
# 1          12         nawala  Commercial, Residential       9/21/2021
# 2          16  mount lavinia              Residential       9/21/2021
# 3          12         nawala  Commercial, Residential       9/21/2021
# 4          22      hokandara              Residential       9/21/2021
#
#    count_govtschools_A  min_dist_govtschools_a  count_govtschools_B  \
# 0                    0                3.099786                    3
# 1                    2                1.530830                   12
# 2                    0                2.727171                    5
# 3                    2                1.530830                   12
# 4                    0                4.673446                    1
#
#    min_dist_govtschools_b  count_semigovtschools  min_dist_semigovtschools  \
# 0                0.190254                      0                  3.899165
# 1                0.863357                      1                  0.906167
# 2                0.191582                      2                  0.581298
# 3                0.863357                      1                  0.906167
# 4                0.386004                      0                  4.412525
#
#    ...  min_dist_nearest_Pvt_Med_center  count_Pvt_Med_Centers  \
# 0  ...                         0.184196                      2
# 1  ...                         2.102498                      0
# 2  ...                         1.188858                      2
# 3  ...                         2.102498                      0
# 4  ...                         4.563302                      0
#
#    min_dist_nearest_Supermarket  count_Supermarkets_within2km  \
# 0                      0.275528                            11
# 1                      0.229320                            17
# 2                      0.113300                            20
# 3                      0.229320                            17
# 4                      1.187704                             5
#
#    min_dist_nearest_Fuel_station  count_Fuel_Stations_within2km  \
# 0                       1.185148                              2
# 1                       1.221396                              4
# 2                       1.052876                              5
# 3                       1.221396                              4
# 4                       0.074059                              1
#
#    Price per Perch  latitude  longitude  current_month
# 0    3,800,000.00   6.897929  79.918872            9.0
# 1    6,500,000.00   6.899527  79.883915            9.0
# 2    2,600,000.00   6.809737  79.871319            9.0
# 3    6,500,000.00   6.897027  79.884947            9.0
# 4      109,090.91   6.884656  79.953253            9.0
#
# [5 rows x 34 columns]

# %% [markdown]
# **Add Columns which help to predict the price range for next months**

# %% [markdown]
# **Below add_month_lowest_highest_columns method adding columns 'X_lowest', 'X_highest' for dataframe. it contains min max values for the month of that Address_ID**

# %%
import pandas as pd

def add_month_lowest_highest_columns(df):
    # Convert Posted_Date_new to datetime with dayfirst=True
    df['Date_new'] = pd.to_datetime(df['Posted_Date_new'], format='%m/%d/%Y', dayfirst=True)

    # Extract month from Posted_Date_new
    df['Month'] = df['Date_new'].dt.to_period('M')

    # Step 1: Group by Address_ID and Month
    grouped_address = df.groupby(['Address_ID', 'Month'])

    # Step 2: For each group, find the min and max values
    result = grouped_address.agg({'Price per Perch': ['min', 'max']}).reset_index()

    # Rename the columns to month_lowest and month_highest
    result.columns = ['Address_ID', 'Month', 'min', 'max']

    # Step 3: Merge the result DataFrame back to the original DataFrame
    df = pd.merge(df, result, on=['Address_ID', 'Month'], how='left')

    # Create a new column for the next month
    df['Next_Month'] = df['Month'].apply(lambda x: x + 1)

    # Step 4: Merge the result DataFrame for the next month back to the original DataFrame
    df = pd.merge(df, result, left_on=['Address_ID', 'Next_Month'], right_on=['Address_ID', 'Month'],
                  suffixes=('_current', '_next'), how='left')

    # Drop the Next_Month column if not needed
    df.drop(['Next_Month'], axis=1, inplace=True)

    return df

# %%
df3 = add_month_lowest_highest_columns(df3)

# %%
df3.drop(['Month_next', 'Month_current', 'Date_new'], axis='columns', inplace=True)
df3
# Out:
#       Address_ID         Address                Land_type Posted_Date_new  \
# 0              6    battaramulla  Commercial, Residential       9/21/2021
# 1             12          nawala  Commercial, Residential       9/21/2021
# 2             16   mount lavinia              Residential       9/21/2021
# 3             12          nawala  Commercial, Residential       9/21/2021
# 4             22       hokandara              Residential       9/21/2021
# ...          ...             ...                      ...             ...
# 3120          10  thalawathugoda              Residential       7/31/2021
# 3121           7          malabe              Residential       7/31/2021
# 3122          21      maharagama              Residential       7/31/2021
# 3123          16   mount lavinia              Residential       7/31/2021
# 3124          14     kahathuduwa       Residential, Other       7/31/2021
#
#       count_govtschools_A  min_dist_govtschools_a  count_govtschools_B  \
# 0                       0                3.099786                    3
# 1                       2                1.530830                   12
# 2                       0                2.727171                    5
# 3                       2                1.530830                   12
# 4                       0                4.673446                    1
# ...                   ...                     ...                  ...
# 3120                    0                3.947032                    1
# 3121                    0                6.499678                    3
# 3122                    0                4.222295                    4
# 3123                    0                2.727171                    5
# 3124                    0                6.507931                    1
#
#       min_dist_govtschools_b  count_semigovtschools  min_dist_semigovtschools  \
# 0                   0.190254                      0                  3.899165
# 1                   0.863357                      1                  0.906167
# 2                   0.191582                      2                  0.581298
# 3                   0.863357                      1                  0.906167
# 4                   0.386004                      0                  4.412525
# ...                      ...                    ...                       ...
# 3120                1.741785                      0                  3.685223
# 3121                0.069944                      0                  6.892376
# 3122                0.369010                      1                  0.382122
# 3123                0.191582                      2                  0.581298
# 3124                1.744546                      0                  6.616528
#
#       ...  min_dist_nearest_Fuel_station  count_Fuel_Stations_within2km  \
# 0     ...                       1.185148                              2
# 1     ...                       1.221396                              4
# 2     ...                       1.052876                              5
# 3     ...                       1.221396                              4
# 4     ...                       0.074059                              1
# ...   ...                            ...                            ...
# 3120  ...                       1.832361                              1
# 3121  ...                       0.327719                              2
# 3122  ...                       0.218560                              3
# 3123  ...                       1.052876                              5
# 3124  ...                       5.118457                              0
#
#       Price per Perch  latitude  longitude  current_month      min_current  \
# 0       3,800,000.00   6.897929  79.918872            9.0    1,400,000.00
# 1       6,500,000.00   6.899527  79.883915            9.0   13,700,000.00
# 2       2,600,000.00   6.809737  79.871319            9.0    1,800,000.00
# 3       6,500,000.00   6.897027  79.884947            9.0   13,700,000.00
# 4         109,090.91   6.884656  79.953253            9.0    1,060,000.00
# ...               ...       ...        ...            ...              ...
# 3120    1,350,000.00   6.878750  79.935589            7.0    1,350,000.00
# 3121    1,500,000.00   6.916685  79.973969            7.0    1,500,000.00
# 3122    1,550,000.00   6.850203  79.926329            7.0    1,550,000.00
# 3123    3,000,000.00   6.825001  79.874762            7.0    3,000,000.00
# 3124      395,000.00   6.780432  79.989545            7.0      395,000.00
#
#          max_current        min_next        max_next
# 0      7,150,000.00              NaN             NaN
# 1      8,500,000.00              NaN             NaN
# 2      5,000,000.00              NaN             NaN
# 3      8,500,000.00              NaN             NaN
# 4        980,000.00              NaN             NaN
# ...              ...             ...             ...
# 3120   1,350,000.00    1,000,000.00      990,000.00
# 3121   1,500,000.00    1,000,000.00      950,000.00
# 3122   1,550,000.00    1,000,000.00      800,000.00
# 3123   3,000,000.00    1,600,000.00    3,200,000.00
# 3124     395,000.00    1,550,000.00      923,076.92
#
# [3125 rows x 38 columns]

# %% [markdown]
# **Explore all features is floats**

# %%
def print_non_float_data(df, column_name):
    try:
        df[column_name].astype(float)
        print(f"Success: {column_name}")
        return True
    except ValueError as e:
        print(f"Error: {column_name}, Error: {e}")
        return False

# %%
excluded_columns = ['Address', 'Land_type', 'Posted_Date_new', 'latitude', 'longitude']

for col in df3.columns:
    if col not in excluded_columns:
        print_non_float_data(df3, col)
# Out:
# Success: Address_ID
# Success: count_govtschools_A
# Success: min_dist_govtschools_a
# Success: count_govtschools_B
# Success: min_dist_govtschools_b
# Success: count_semigovtschools
# Success: min_dist_semigovtschools
# Success: count_intlschools
# Success: min_dist_intlschools
# Success: count_uni
# Success: min_dist_uni
# Success: min_dist_nearest_express
# Success: min_dist_nearest_railway
# Success: min_dist_nearest_bank
# Success: count_banks_within_2km
# Success: min_dist_nearest_FinanceCompany
# Success: count_FinanceCompanies_within_2km
# Success: min_dist_nearest_Govt_Hospital
# Success: count_Govt_Hospitals
# Success: min_dist_nearest_Pvt_Hospital
# Success: count_Pvt_Hospital
# Success: min_dist_nearest_Pvt_Med_center
# Success: count_Pvt_Med_Centers
# Success: min_dist_nearest_Supermarket
# Success: count_Supermarkets_within2km
# Success: min_dist_nearest_Fuel_station
# Success: count_Fuel_Stations_within2km
# Error: Price per Perch, Error: could not convert string to float: ' 3,800,000.00 '
# Success: current_month
# Error: min_current, Error: could not convert string to float: ' 1,400,000.00 '
# Error: max_current, Error: could not convert string to float: ' 7,150,000.00 '
# Error: min_next, Error: could not convert string to float: ' 2,092,050.21 '
# Error: max_next, Error: could not convert string to float: ' 6,500,000.00 '

# %% [markdown]
# **Above shows that 'Price per Perch' can be '3,800,000.00'. For such case we can replace commace and spaces. Then can convert into float.**

# %% [markdown]
# **'Price per perch' feature transformation**

# %%
def transformtoPrices(value):
    try:
        return float(value.replace(' ', '').replace(',', ''))
    except:
        if pd.isna(value):
            return 0
        else: return value

# %%
df4 = df3.copy()
df4['Price per Perch'] = df3['Price per Perch'].apply(transformtoPrices)
print_non_float_data(df4, 'Price per Perch')
# Out:
# Success: Price per Perch
# True

# %%
df4['min_current'] = df3['min_current'].apply(transformtoPrices)
print_non_float_data(df4, 'min_current')
# Out:
# Success: min_current
# True

# %%
df4['max_current'] = df3['max_current'].apply(transformtoPrices)
print_non_float_data(df4, 'max_current')
# Out:
# Success: max_current
# True

# %%
df4['min_next'] = df3['min_next'].apply(transformtoPrices)
print_non_float_data(df4, 'min_next')
# Out:
# Success: min_next
# True

# %%
df4['max_next'] = df3['max_next'].apply(transformtoPrices)
print_non_float_data(df4, 'max_next')
# Out:
# Success: max_next
# True

# %%
excluded_columns = ['Address', 'Land_type', 'Posted_Date_new', 'latitude', 'longitude']

for col in df4.columns:
    if col not in excluded_columns:
        print_non_float_data(df4, col)
# Out:
# Success: Address_ID
# Success: count_govtschools_A
# Success: min_dist_govtschools_a
# Success: count_govtschools_B
# Success: min_dist_govtschools_b
# Success: count_semigovtschools
# Success: min_dist_semigovtschools
# Success: count_intlschools
# Success: min_dist_intlschools
# Success: count_uni
# Success: min_dist_uni
# Success: min_dist_nearest_express
# Success: min_dist_nearest_railway
# Success: min_dist_nearest_bank
# Success: count_banks_within_2km
# Success: min_dist_nearest_FinanceCompany
# Success: count_FinanceCompanies_within_2km
# Success: min_dist_nearest_Govt_Hospital
# Success: count_Govt_Hospitals
# Success: min_dist_nearest_Pvt_Hospital
# Success: count_Pvt_Hospital
# Success: min_dist_nearest_Pvt_Med_center
# Success: count_Pvt_Med_Centers
# Success: min_dist_nearest_Supermarket
# Success: count_Supermarkets_within2km
# Success: min_dist_nearest_Fuel_station
# Success: count_Fuel_Stations_within2km
# Success: Price per Perch
# Success: current_month
# Success: min_current
# Success: max_current
# Success: min_next
# Success: max_next

# %% [markdown]
# **For below row, it shows now data row how it is now**

# %%
df4.loc[30]
# Out:
# Address_ID                                     1
# Address                                   ranala
# Land_type                            Residential
# Posted_Date_new                        9/20/2021
# count_govtschools_A                            0
# min_dist_govtschools_a                 11.681242
# count_govtschools_B                            0
# min_dist_govtschools_b                  3.699442
# count_semigovtschools                          0
# min_dist_semigovtschools                8.071884
# count_intlschools                              0
# min_dist_intlschools                    8.062805
# count_uni                                      0
# min_dist_uni                            7.028561
# min_dist_nearest_express                6.124351
# min_dist_nearest_railway                7.643559
# min_dist_nearest_bank                   1.844833
# count_banks_within_2km                         1
# min_dist_nearest_FinanceCompany           4.8532
# count_FinanceCompanies_within_2km              0
# min_dist_nearest_Govt_Hospital          9.156113
# count_Govt_Hospitals                           0
# min_dist_nearest_Pvt_Hospital           10.52137
# count_Pvt_Hospital                             0
# min_dist_nearest_Pvt_Med_center          5.97052
# count_Pvt_Med_Centers                          0
# min_dist_nearest_Supermarket            1.969323
# count_Supermarkets_within2km                   1
# min_dist_nearest_Fuel_station           1.735536
# count_Fuel_Stations_within2km                  1
# Price per Perch                         450000.0
# latitude                                6.906866
# longitude                              80.036605
# current_month                                9.0
# min_current                             275000.0
# max_current                              98425.2
# min_next                                     0.0
# max_next                                     0.0
# Name: 30, dtype: object

# %% [markdown]
# **Convert Land_type into a numeric value**

# %%
df4['Land_type'].unique()
# Out:
# array(['Commercial, Residential', 'Residential',
#        'Commercial, Residential, Other', 'Commercial',
#        'Residential, Other',
#        'Agricultural, Commercial, Residential, Other',
#        'Agricultural, Commercial, Residential', 'Commercial, Other',
#        'Other', 'Agricultural, Residential',
#        'Agricultural, Residential, Other', 'Agricultural',
#        'Agricultural, Commercial'], dtype=object)

# %% [markdown]
# **From above result can see there can be few types of Land_types for a each land or one Land_type. So we can do something like that.Lets assign values like 1, 2, 3, 4 to each Land_type. And assign like below**

# %% [markdown]
# **lets assign Agricultural as 1, Commercial as 2, Residential as 3, Other as 4**

# %% [markdown]
# **Example: Land_type of A land='Agricultural, Commercial, Residential, Other'. So land_type will '1+2+3+4=10'**

# %%
switch_dict = {
    'Agricultural': 1,
    'Commercial': 2,
    'Residential': 3,
    'Other': 4
}

def landTypeValueGeneration(landType):
    landTypeValue = 0
    
    for key, value in switch_dict.items():
        if key in landType:
            landTypeValue+=value
            
    return landTypeValue

# %%
df5 = df4.copy()
df5['Land_type'] = df5['Land_type'].apply(landTypeValueGeneration)
df5.head()
# Out:
#    Address_ID        Address  Land_type Posted_Date_new  count_govtschools_A  \
# 0           6   battaramulla          5       9/21/2021                    0
# 1          12         nawala          5       9/21/2021                    2
# 2          16  mount lavinia          3       9/21/2021                    0
# 3          12         nawala          5       9/21/2021                    2
# 4          22      hokandara          3       9/21/2021                    0
#
#    min_dist_govtschools_a  count_govtschools_B  min_dist_govtschools_b  \
# 0                3.099786                    3                0.190254
# 1                1.530830                   12                0.863357
# 2                2.727171                    5                0.191582
# 3                1.530830                   12                0.863357
# 4                4.673446                    1                0.386004
#
#    count_semigovtschools  min_dist_semigovtschools  ...  \
# 0                      0                  3.899165  ...
# 1                      1                  0.906167  ...
# 2                      2                  0.581298  ...
# 3                      1                  0.906167  ...
# 4                      0                  4.412525  ...
#
#    min_dist_nearest_Fuel_station  count_Fuel_Stations_within2km  \
# 0                       1.185148                              2
# 1                       1.221396                              4
# 2                       1.052876                              5
# 3                       1.221396                              4
# 4                       0.074059                              1
#
#    Price per Perch  latitude  longitude  current_month  min_current  \
# 0       3800000.00  6.897929  79.918872            9.0    1400000.0
# 1       6500000.00  6.899527  79.883915            9.0   13700000.0
# 2       2600000.00  6.809737  79.871319            9.0    1800000.0
# 3       6500000.00  6.897027  79.884947            9.0   13700000.0
# 4        109090.91  6.884656  79.953253            9.0    1060000.0
#
#    max_current  min_next  max_next
# 0    7150000.0       0.0       0.0
# 1    8500000.0       0.0       0.0
# 2    5000000.0       0.0       0.0
# 3    8500000.0       0.0       0.0
# 4     980000.0       0.0       0.0
#
# [5 rows x 38 columns]

# %%
df5['Land_type'].unique()
# Out:
# array([ 5,  3,  9,  2,  7, 10,  6,  4,  8,  1], dtype=int64)

# %%
df5.to_csv("Cleaned.csv", index=False)

# %%
df5.shape
# Out:
# (3125, 38)

# %%
df5.head(10)
# Out:
#    Address_ID         Address  Land_type Posted_Date_new  count_govtschools_A  \
# 0           6    battaramulla          5       9/21/2021                    0
# 1          12          nawala          5       9/21/2021                    2
# 2          16   mount lavinia          3       9/21/2021                    0
# 3          12          nawala          5       9/21/2021                    2
# 4          22       hokandara          3       9/21/2021                    0
# 5           6    battaramulla          3       9/21/2021                    0
# 6          12          nawala          3       9/21/2021                    2
# 7           3        kaduwela          3       9/21/2021                    0
# 8          10  thalawathugoda          3       9/21/2021                    0
# 9          17    athurugiriya          3       9/21/2021                    0
#
#    min_dist_govtschools_a  count_govtschools_B  min_dist_govtschools_b  \
# 0                3.099786                    3                0.190254
# 1                1.530830                   12                0.863357
# 2                2.727171                    5                0.191582
# 3                1.530830                   12                0.863357
# 4                4.673446                    1                0.386004
# 5                3.099786                    3                0.190254
# 6                1.530830                   12                0.863357
# 7               10.998007                    2                0.686802
# 8                3.947032                    1                1.741785
# 9                5.178703                    1                0.359089
#
#    count_semigovtschools  min_dist_semigovtschools  ...  \
# 0                      0                  3.899165  ...
# 1                      1                  0.906167  ...
# 2                      2                  0.581298  ...
# 3                      1                  0.906167  ...
# 4                      0                  4.412525  ...
# 5                      0                  3.899165  ...
# 6                      1                  0.906167  ...
# 7                      0                 10.301645  ...
# 8                      0                  3.685223  ...
# 9                      0                  3.821033  ...
#
#    min_dist_nearest_Fuel_station  count_Fuel_Stations_within2km  \
# 0                       1.185148                              2
# 1                       1.221396                              4
# 2                       1.052876                              5
# 3                       1.221396                              4
# 4                       0.074059                              1
# 5                       1.185148                              2
# 6                       1.221396                              4
# 7                       0.044349                              1
# 8                       1.832361                              1
# 9                       0.132467                              1
#
#    Price per Perch  latitude  longitude  current_month  min_current  \
# 0       3800000.00  6.897929  79.918872            9.0    1400000.0
# 1       6500000.00  6.899527  79.883915            9.0   13700000.0
# 2       2600000.00  6.809737  79.871319            9.0    1800000.0
# 3       6500000.00  6.897027  79.884947            9.0   13700000.0
# 4        109090.91  6.884656  79.953253            9.0    1060000.0
# 5       6000000.00  6.903295  79.913055            9.0    1400000.0
# 6       5185185.19  6.900611  79.894373            9.0   13700000.0
# 7       1200000.00  6.932291  79.976467            9.0    1200000.0
# 8       2200000.00  6.876957  79.932224            9.0    1000000.0
# 9        675000.00  6.870700  80.005811            9.0    1000000.0
#
#    max_current  min_next  max_next
# 0    7150000.0       0.0       0.0
# 1    8500000.0       0.0       0.0
# 2    5000000.0       0.0       0.0
# 3    8500000.0       0.0       0.0
# 4     980000.0       0.0       0.0
# 5    7150000.0       0.0       0.0
# 6    8500000.0       0.0       0.0
# 7     725000.0       0.0       0.0
# 8    9900000.0       0.0       0.0
# 9     987500.0       0.0       0.0
#
# [10 rows x 38 columns]

# %% [markdown]
# <h2 style='color:blue'>Outlier Removal Using Standard Deviation and Mean</h2>

# %%
pd.options.display.float_format = '{:,.2f}'.format
df5['Price per Perch'].describe()
# Out:
# count        3,125.00
# mean     1,617,822.65
# std      2,167,399.00
# min         30,000.00
# 25%        450,000.00
# 50%        890,000.00
# 75%      2,100,000.00
# max     40,000,000.00
# Name: Price per Perch, dtype: float64

# %%
df5.shape
# Out:
# (3125, 38)

# %% [markdown]
# **Here we find that min price per perch is 30,000.00 rs/sqft whereas max is 40,000,000.00, this shows a wide variation in property prices. We should remove outliers per location using mean and one standard deviation. This will remove some of outliers**

# %%
def replace_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('Address_ID'):
        m = np.mean(subdf['Price per Perch'])
        st = np.std(subdf['Price per Perch'])
        
        # Identify and replace outliers with the median value
        outliers = (subdf['Price per Perch'] < (m - st)) | (subdf['Price per Perch'] > (m + st))
        subdf.loc[outliers, 'Price per Perch'] = subdf['Price per Perch'].median()
        
        df_out = pd.concat([df_out, subdf], ignore_index=True)
    return df_out


pd.reset_option('display.float_format')
df6 = replace_pps_outliers(df5)
df6.head()
# Out:
#    Address_ID Address  Land_type Posted_Date_new  count_govtschools_A  \
# 0           1  ranala          3       9/20/2021                    0
# 1           1  ranala          3       9/20/2021                    0
# 2           1  ranala          3       9/20/2021                    0
# 3           1  ranala          7       9/20/2021                    0
# 4           1  ranala          3       9/20/2021                    0
#
#    min_dist_govtschools_a  count_govtschools_B  min_dist_govtschools_b  \
# 0               11.681242                    0                3.699442
# 1               11.681242                    0                3.699442
# 2               11.681242                    0                3.699442
# 3               11.681242                    0                3.699442
# 4               11.681242                    0                3.699442
#
#    count_semigovtschools  min_dist_semigovtschools  ...  \
# 0                      0                  8.071884  ...
# 1                      0                  8.071884  ...
# 2                      0                  8.071884  ...
# 3                      0                  8.071884  ...
# 4                      0                  8.071884  ...
#
#    min_dist_nearest_Fuel_station  count_Fuel_Stations_within2km  \
# 0                       1.735536                              1
# 1                       1.735536                              1
# 2                       1.735536                              1
# 3                       1.735536                              1
# 4                       1.735536                              1
#
#    Price per Perch  latitude  longitude  current_month  min_current  \
# 0         625000.0  6.916670  80.022399            9.0     275000.0
# 1         450000.0  6.922242  80.028647            9.0     275000.0
# 2         450000.0  6.906866  80.036605            9.0     275000.0
# 3         600000.0  6.924536  80.025059            9.0     275000.0
# 4         600000.0  6.920455  80.023331            9.0     275000.0
#
#    max_current  min_next  max_next
# 0      98425.2       0.0       0.0
# 1      98425.2       0.0       0.0
# 2      98425.2       0.0       0.0
# 3      98425.2       0.0       0.0
# 4      98425.2       0.0       0.0
#
# [5 rows x 38 columns]

# %%
# def remove_pps_outliers(df):
#     df_out = pd.DataFrame()
#     for key, subdf in df.groupby('Address_ID'):
#         m = np.mean(subdf['Price per Perch'])
#         st = np.std(subdf['Price per Perch'])
#         reduced_df = subdf[(subdf['Price per Perch']>(m-st)) & (subdf['Price per Perch']<=(m+st))]
#         df_out = pd.concat([df_out,reduced_df],ignore_index=True)
#     return df_out

# df7 = remove_pps_outliers(df5)
# df7.head()

# %%
df6['Land_type'].value_counts()
df6.head()
# Out:
#    Address_ID Address  Land_type Posted_Date_new  count_govtschools_A  \
# 0           1  ranala          3       9/20/2021                    0
# 1           1  ranala          3       9/20/2021                    0
# 2           1  ranala          3       9/20/2021                    0
# 3           1  ranala          7       9/20/2021                    0
# 4           1  ranala          3       9/20/2021                    0
#
#    min_dist_govtschools_a  count_govtschools_B  min_dist_govtschools_b  \
# 0               11.681242                    0                3.699442
# 1               11.681242                    0                3.699442
# 2               11.681242                    0                3.699442
# 3               11.681242                    0                3.699442
# 4               11.681242                    0                3.699442
#
#    count_semigovtschools  min_dist_semigovtschools  ...  \
# 0                      0                  8.071884  ...
# 1                      0                  8.071884  ...
# 2                      0                  8.071884  ...
# 3                      0                  8.071884  ...
# 4                      0                  8.071884  ...
#
#    min_dist_nearest_Fuel_station  count_Fuel_Stations_within2km  \
# 0                       1.735536                              1
# 1                       1.735536                              1
# 2                       1.735536                              1
# 3                       1.735536                              1
# 4                       1.735536                              1
#
#    Price per Perch  latitude  longitude  current_month  min_current  \
# 0         625000.0  6.916670  80.022399            9.0     275000.0
# 1         450000.0  6.922242  80.028647            9.0     275000.0
# 2         450000.0  6.906866  80.036605            9.0     275000.0
# 3         600000.0  6.924536  80.025059            9.0     275000.0
# 4         600000.0  6.920455  80.023331            9.0     275000.0
#
#    max_current  min_next  max_next
# 0      98425.2       0.0       0.0
# 1      98425.2       0.0       0.0
# 2      98425.2       0.0       0.0
# 3      98425.2       0.0       0.0
# 4      98425.2       0.0       0.0
#
# [5 rows x 38 columns]

# %%
df6['Address'].value_counts()
# Out:
# Address
# ranala            350
# makandana         270
# kaduwela          250
# kesbewa           206
# piliyandala       204
# battaramulla      188
# malabe            155
# nugegoda          132
# madapatha         125
# thalawathugoda    122
# bomiriya          121
# nawala            111
# bope              107
# dehiwala          102
# kahathuduwa        91
# homagama           86
# athurugiriya       85
# mount lavinia      79
# boralesgamuwa      59
# pitakotte          58
# maharagama         58
# hokandara          57
# diyagama           56
# kirulapone         53
# Name: count, dtype: int64

# %% [markdown]
# **Let's check if for a given location how does the 2 BHK and 3 BHK property prices look like**

# %%
def plot_scatter_chart(df, location):
    plt.figure(figsize=(15, 10))

    # Select data for the specified location
    location_data = df[df['Address'] == location]

    # Use Seaborn's scatterplot to display all possible combinations
    sns.scatterplot(x='Land_type', y='Price per Perch', hue='Land_type', data=location_data, palette='viridis', s=50)

    plt.xlabel("Land types total")
    plt.ylabel("Price LKR")
    plt.title(location)
    plt.legend(title='Land Type')

    plt.show()
    
plot_scatter_chart(df6,"ranala")

# %%
plot_scatter_chart(df6,"makandana")

# %%
pd.options.display.float_format = '{:.15f}'.format
df7 =df6.drop(['Address'], axis='columns')

# Display the DataFrame
df7.head()
# Out:
#    Address_ID  Land_type Posted_Date_new  count_govtschools_A  \
# 0           1          3       9/20/2021                    0
# 1           1          3       9/20/2021                    0
# 2           1          3       9/20/2021                    0
# 3           1          7       9/20/2021                    0
# 4           1          3       9/20/2021                    0
#
#    min_dist_govtschools_a  count_govtschools_B  min_dist_govtschools_b  \
# 0      11.681242470000001                    0       3.699442392000000
# 1      11.681242470000001                    0       3.699442392000000
# 2      11.681242470000001                    0       3.699442392000000
# 3      11.681242470000001                    0       3.699442392000000
# 4      11.681242470000001                    0       3.699442392000000
#
#    count_semigovtschools  min_dist_semigovtschools  count_intlschools  ...  \
# 0                      0         8.071884081000000                  0  ...
# 1                      0         8.071884081000000                  0  ...
# 2                      0         8.071884081000000                  0  ...
# 3                      0         8.071884081000000                  0  ...
# 4                      0         8.071884081000000                  0  ...
#
#    min_dist_nearest_Fuel_station  count_Fuel_Stations_within2km  \
# 0              1.735535589000000                              1
# 1              1.735535589000000                              1
# 2              1.735535589000000                              1
# 3              1.735535589000000                              1
# 4              1.735535589000000                              1
#
#          Price per Perch          latitude          longitude  \
# 0 625000.000000000000000 6.916669694423810 80.022398512135794
# 1 450000.000000000000000 6.922242120978898 80.028646950214565
# 2 450000.000000000000000 6.906866463052855 80.036604718179078
# 3 600000.000000000000000 6.924536355831947 80.025058542457145
# 4 600000.000000000000000 6.920455440986516 80.023331042228108
#
#       current_month            min_current           max_current  \
# 0 9.000000000000000 275000.000000000000000 98425.199999999997090
# 1 9.000000000000000 275000.000000000000000 98425.199999999997090
# 2 9.000000000000000 275000.000000000000000 98425.199999999997090
# 3 9.000000000000000 275000.000000000000000 98425.199999999997090
# 4 9.000000000000000 275000.000000000000000 98425.199999999997090
#
#            min_next          max_next
# 0 0.000000000000000 0.000000000000000
# 1 0.000000000000000 0.000000000000000
# 2 0.000000000000000 0.000000000000000
# 3 0.000000000000000 0.000000000000000
# 4 0.000000000000000 0.000000000000000
#
# [5 rows x 37 columns]

# %%
df7 = df7.drop(['Posted_Date_new'], axis='columns')
pd.reset_option('display.float_format')
df7.head()
# Out:
#    Address_ID  Land_type  count_govtschools_A  min_dist_govtschools_a  \
# 0           1          3                    0               11.681242
# 1           1          3                    0               11.681242
# 2           1          3                    0               11.681242
# 3           1          7                    0               11.681242
# 4           1          3                    0               11.681242
#
#    count_govtschools_B  min_dist_govtschools_b  count_semigovtschools  \
# 0                    0                3.699442                      0
# 1                    0                3.699442                      0
# 2                    0                3.699442                      0
# 3                    0                3.699442                      0
# 4                    0                3.699442                      0
#
#    min_dist_semigovtschools  count_intlschools  min_dist_intlschools  ...  \
# 0                  8.071884                  0              8.062805  ...
# 1                  8.071884                  0              8.062805  ...
# 2                  8.071884                  0              8.062805  ...
# 3                  8.071884                  0              8.062805  ...
# 4                  8.071884                  0              8.062805  ...
#
#    min_dist_nearest_Fuel_station  count_Fuel_Stations_within2km  \
# 0                       1.735536                              1
# 1                       1.735536                              1
# 2                       1.735536                              1
# 3                       1.735536                              1
# 4                       1.735536                              1
#
#    Price per Perch  latitude  longitude  current_month  min_current  \
# 0         625000.0  6.916670  80.022399            9.0     275000.0
# 1         450000.0  6.922242  80.028647            9.0     275000.0
# 2         450000.0  6.906866  80.036605            9.0     275000.0
# 3         600000.0  6.924536  80.025059            9.0     275000.0
# 4         600000.0  6.920455  80.023331            9.0     275000.0
#
#    max_current  min_next  max_next
# 0      98425.2       0.0       0.0
# 1      98425.2       0.0       0.0
# 2      98425.2       0.0       0.0
# 3      98425.2       0.0       0.0
# 4      98425.2       0.0       0.0
#
# [5 rows x 36 columns]

# %% [markdown]
# <h2 style='color:blue'>Build a Model Now...</h2>

# %%
df7.shape
# Out:
# (3125, 36)

# %%
df7.isna().sum()
df7.head()
# Out:
#    Address_ID  Land_type  count_govtschools_A  min_dist_govtschools_a  \
# 0           1          3                    0               11.681242
# 1           1          3                    0               11.681242
# 2           1          3                    0               11.681242
# 3           1          7                    0               11.681242
# 4           1          3                    0               11.681242
#
#    count_govtschools_B  min_dist_govtschools_b  count_semigovtschools  \
# 0                    0                3.699442                      0
# 1                    0                3.699442                      0
# 2                    0                3.699442                      0
# 3                    0                3.699442                      0
# 4                    0                3.699442                      0
#
#    min_dist_semigovtschools  count_intlschools  min_dist_intlschools  ...  \
# 0                  8.071884                  0              8.062805  ...
# 1                  8.071884                  0              8.062805  ...
# 2                  8.071884                  0              8.062805  ...
# 3                  8.071884                  0              8.062805  ...
# 4                  8.071884                  0              8.062805  ...
#
#    min_dist_nearest_Fuel_station  count_Fuel_Stations_within2km  \
# 0                       1.735536                              1
# 1                       1.735536                              1
# 2                       1.735536                              1
# 3                       1.735536                              1
# 4                       1.735536                              1
#
#    Price per Perch  latitude  longitude  current_month  min_current  \
# 0         625000.0  6.916670  80.022399            9.0     275000.0
# 1         450000.0  6.922242  80.028647            9.0     275000.0
# 2         450000.0  6.906866  80.036605            9.0     275000.0
# 3         600000.0  6.924536  80.025059            9.0     275000.0
# 4         600000.0  6.920455  80.023331            9.0     275000.0
#
#    max_current  min_next  max_next
# 0      98425.2       0.0       0.0
# 1      98425.2       0.0       0.0
# 2      98425.2       0.0       0.0
# 3      98425.2       0.0       0.0
# 4      98425.2       0.0       0.0
#
# [5 rows x 36 columns]

# %%
x = df7.drop(['Price per Perch', 'min_next', 'max_next'],axis='columns')
x.head(3)
# Out:
#    Address_ID  Land_type  count_govtschools_A  min_dist_govtschools_a  \
# 0           1          3                    0               11.681242
# 1           1          3                    0               11.681242
# 2           1          3                    0               11.681242
#
#    count_govtschools_B  min_dist_govtschools_b  count_semigovtschools  \
# 0                    0                3.699442                      0
# 1                    0                3.699442                      0
# 2                    0                3.699442                      0
#
#    min_dist_semigovtschools  count_intlschools  min_dist_intlschools  ...  \
# 0                  8.071884                  0              8.062805  ...
# 1                  8.071884                  0              8.062805  ...
# 2                  8.071884                  0              8.062805  ...
#
#    count_Pvt_Med_Centers  min_dist_nearest_Supermarket  \
# 0                      0                      1.969323
# 1                      0                      1.969323
# 2                      0                      1.969323
#
#    count_Supermarkets_within2km  min_dist_nearest_Fuel_station  \
# 0                             1                       1.735536
# 1                             1                       1.735536
# 2                             1                       1.735536
#
#    count_Fuel_Stations_within2km  latitude  longitude  current_month  \
# 0                              1  6.916670  80.022399            9.0
# 1                              1  6.922242  80.028647            9.0
# 2                              1  6.906866  80.036605            9.0
#
#    min_current  max_current
# 0     275000.0      98425.2
# 1     275000.0      98425.2
# 2     275000.0      98425.2
#
# [3 rows x 33 columns]

# %%
y = df7[['Price per Perch', 'min_next', 'max_next']]
y.head(3)
# Out:
#    Price per Perch  min_next  max_next
# 0         625000.0       0.0       0.0
# 1         450000.0       0.0       0.0
# 2         450000.0       0.0       0.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test)
# Out:
# 0.7318112600381951

# %% [markdown]
# <h2 style='color:blue'>Use K Fold cross validation to measure accuracy of our LinearRegression model</h2>

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), x, y, cv=cv)
# Out:
# array([0.74180915, 0.79035863, 0.7510035 , 0.75825657, 0.77832815])

# %% [markdown]
# **We can see that in 5 iterations we get a score above 75% all the time. This is pretty good but we want to test few other algorithms for regression to see if we can get even better score. We will use GridSearchCV for this purpose**

# %% [markdown]
# <h2 style='color:blue'>Find best model using GridSearchCV</h2>

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor

def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {}
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        },
        'mlp_regressor': {
            'model': MLPRegressor(),
            'params': {
                'hidden_layer_sizes': [(50), (100), (50, 50)],
                'activation': ['relu', 'tanh'],
                'solver': ['adam', 'lbfgs'],
                'alpha': [0.0001, 0.001, 0.01],
                'learning_rate': ['constant', 'invscaling', 'adaptive']
            }
        }
    }
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(x,y)
# Out:
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.322e+14, tolerance: 5.173e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.120e+15, tolerance: 8.928e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.422e+15, tolerance: 1.737e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.265e+14, tolerance: 4.990e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.063e+15, tolerance: 7.907e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.428e+15, tolerance: 1.657e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.253e+14, tolerance: 5.137e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.143e+15, tolerance: 9.019e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.483e+15, tolerance: 1.743e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.379e+14, tolerance: 4.973e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.805e+14, tolerance: 7.825e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.381e+15, tolerance: 1.709e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.296e+14, tolerance: 4.989e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.016e+15, tolerance: 7.991e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.471e+15, tolerance: 1.687e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.321e+14, tolerance: 5.173e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.100e+15, tolerance: 8.928e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.422e+15, tolerance: 1.737e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.265e+14, tolerance: 4.990e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.045e+15, tolerance: 7.907e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.428e+15, tolerance: 1.657e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.252e+14, tolerance: 5.137e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.124e+15, tolerance: 9.019e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.483e+15, tolerance: 1.743e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.379e+14, tolerance: 4.973e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.607e+14, tolerance: 7.825e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.381e+15, tolerance: 1.709e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.296e+14, tolerance: 4.989e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.999e+14, tolerance: 7.991e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.471e+15, tolerance: 1.687e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.321e+14, tolerance: 5.173e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.120e+15, tolerance: 8.928e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.422e+15, tolerance: 1.737e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.265e+14, tolerance: 4.990e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.063e+15, tolerance: 7.907e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.428e+15, tolerance: 1.657e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.253e+14, tolerance: 5.137e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.140e+15, tolerance: 9.019e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.483e+15, tolerance: 1.743e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.379e+14, tolerance: 4.973e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.804e+14, tolerance: 7.825e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.381e+15, tolerance: 1.709e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.296e+14, tolerance: 4.989e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.016e+15, tolerance: 7.991e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.471e+15, tolerance: 1.687e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.321e+14, tolerance: 5.173e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.101e+15, tolerance: 8.928e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.422e+15, tolerance: 1.737e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.265e+14, tolerance: 4.990e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.045e+15, tolerance: 7.907e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.428e+15, tolerance: 1.657e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.252e+14, tolerance: 5.137e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.124e+15, tolerance: 9.019e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.483e+15, tolerance: 1.743e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.379e+14, tolerance: 4.973e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.608e+14, tolerance: 7.825e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.381e+15, tolerance: 1.709e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.296e+14, tolerance: 4.989e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.000e+15, tolerance: 7.991e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.471e+15, tolerance: 1.687e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.191e+14, tolerance: 6.349e+11
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.325e+15, tolerance: 1.048e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.057e+15, tolerance: 2.125e+12
#   model = cd_fast.enet_coordinate_descent(
# c:\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Python312\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "c:\Python312\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'absolute_error', 'squared_error', 'poisson'}. Got 'mse' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Python312\Lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.90319201 0.8942667 ]
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
#                model  best_score  \
# 0  linear_regression    0.763951
# 1              lasso    0.763713
# 2      decision_tree    0.903192
# 3      mlp_regressor    0.616397
#
#                                          best_params
# 0                                                 {}
# 1                {'alpha': 2, 'selection': 'cyclic'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}
# 3  {'activation': 'relu', 'alpha': 0.01, 'hidden_...

# %% [markdown]
# **Based on above results we can say that LinearRegression gives the best score. Hence we will use that.**

# %% [markdown]
# <h2 style='color:blue'>Test the model for few properties</h2>

# %%
def predict_price(location,sqft,bath,bhk):    
    loc_index = np.where(X.columns==location)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = sqft
    x[1] = bath
    x[2] = bhk
    if loc_index >= 0:
        x[loc_index] = 1

    return lr_clf.predict([x])[0]

# %%
predict_price('1st Phase JP Nagar',1000, 2, 2)
# Out:
# 83.86570258311222

# %%
predict_price('1st Phase JP Nagar',1000, 3, 3)
# Out:
# 86.08062284985995

# %%
predict_price('Indira Nagar',1000, 2, 2)
# Out:
# 193.31197733179556

# %%
predict_price('Indira Nagar',1000, 3, 3)
# Out:
# 195.52689759854331

# %% [markdown]
# <h2 style='color:blue'>Export the tested model to a pickle file</h2>

# %%
import pickle
with open('banglore_home_prices_model.pickle','wb') as f:
    pickle.dump(lr_clf,f)

# %% [markdown]
# <h2 style='color:blue'>Export location and column information to a file that will be useful later on in our prediction application</h2>

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
